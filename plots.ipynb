# %% [markdown]
# # Performance
#
# ## bi-lstm_lr-0.5_training_stats
# Accuracy: 0.8800959232613909
# Predicted tags: 9591
# Number of POS tags: 18
#
# ## lstm_lr-0.5_training_stats
# Accuracy: 0.8331769367115004
# Predicted tags: 9591
# Number of POS tags: 18
#
# ## bi-lstm_lr-0.1_training_stats
# Accuracy: 0.7562297987696799
# Predicted tags: 9591
# Number of POS tags: 18
#
# ## lstm_lr-0.1_training_stats
# Accuracy: 0.7089980189761235
# Predicted tags: 9591
# Number of POS tags: 18

# %%
import pandas as pd
df1 = pd.read_csv("bi-lstm_lr-0.5_training_stats.csv")
df2 = pd.read_csv("lstm_lr-0.5_training_stats.csv")

import matplotlib.pyplot as plt

plt.title('Loss Comparison (lr=0.5)')
plt.xlabel('epochs')
plt.ylabel('avg loss')
plt.grid()
plt.plot(df1["dev_loss"], "lime", label="bi-lstm_dev")
plt.plot(df1["train_loss"], "lightgreen", label="bi-lstm_train")
plt.plot(df2["dev_loss"], "red", label="lstm_dev")
plt.plot(df2["train_loss"], "salmon", label="lstm_train")
plt.legend()

plt.savefig("figures/lstm_lr-0.5_loss_comparison.png", dpi=200)
plt.show()

import matplotlib.pyplot as plt

plt.title('Accuracy Comparison (lr=0.5)')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()
plt.plot(df1["dev_accuracy"], "lime", label="bi-lstm_dev")
plt.plot(df1["train_accuracy"], "lightgreen", label="bi-lstm_train")
plt.plot(df2["dev_accuracy"], "red", label="lstm_dev")
plt.plot(df2["train_accuracy"], "salmon", label="lstm_train")
plt.legend()

plt.savefig("figures/lstm_lr-0.5_accu_comparison.png", dpi=200)
plt.show()

# %%
import pandas as pd
df1 = pd.read_csv("bi-lstm_lr-0.1_training_stats.csv")
df2 = pd.read_csv("lstm_lr-0.1_training_stats.csv")

import matplotlib.pyplot as plt

plt.title('Loss Comparison (lr=0.1)')
plt.xlabel('epochs')
plt.ylabel('avg loss')
plt.grid()
plt.plot(df1["dev_loss"], "lime", label="bi-lstm_dev")
plt.plot(df1["train_loss"], "lightgreen", label="bi-lstm_train")
plt.plot(df2["dev_loss"], "red", label="lstm_dev")
plt.plot(df2["train_loss"], "salmon", label="lstm_train")
plt.legend()

plt.savefig("figures/lstm_lr-0.1_loss_comparison.png", dpi=200)
plt.show()

import matplotlib.pyplot as plt

plt.title('Accuracy Comparison (lr=0.1)')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()
plt.plot(df1["dev_accuracy"], "lime", label="bi-lstm_dev")
plt.plot(df1["train_accuracy"], "lightgreen", label="bi-lstm_train")
plt.plot(df2["dev_accuracy"], "red", label="lstm_dev")
plt.plot(df2["train_accuracy"], "salmon", label="lstm_train")
plt.legend()

plt.savefig("figures/lstm_lr-0.1_accu_comparison.png", dpi=200)
plt.show()

# %%
df1 = pd.read_csv("bi-lstm_lr-0.5_training_stats.csv")
df2 = pd.read_csv("lstm_lr-0.5_training_stats.csv")
df3 = pd.read_csv("bi-lstm_lr-0.1_training_stats.csv")
df4 = pd.read_csv("lstm_lr-0.1_training_stats.csv")

print(df1.describe())
print(df2.describe())
print(df3.describe())
print(df4.describe())
# Out:
#        Unnamed: 0  dev_accuracy    dev_loss  train_accuracy  train_loss
# count  100.000000    100.000000  100.000000      100.000000  100.000000
# mean    49.500000      0.835094    2.143245        0.869399    2.109559
# std     29.011492      0.066603    0.064609        0.082517    0.080666
# min      0.000000      0.579118    2.096154        0.580779    2.045937
# 25%     24.750000      0.767253    2.099317        0.786144    2.047243
# 50%     49.500000      0.879254    2.100676        0.919405    2.059946
# 75%     74.250000      0.880747    2.208516        0.933672    2.190420
# max     99.000000      0.883653    2.397859        0.935219    2.398944
#        Unnamed: 0  dev_accuracy    dev_loss  train_accuracy  train_loss
# count  100.000000    100.000000  100.000000      100.000000  100.000000
# mean    49.500000      0.807621    2.170420        0.837415    2.139204
# std     29.011492      0.049190    0.047056        0.064273    0.062674
# ...
